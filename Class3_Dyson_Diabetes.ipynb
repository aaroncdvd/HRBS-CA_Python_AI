# %% [markdown]
# <a href="https://colab.research.google.com/github/aaroncdvd/HRBS-CA_Python_AI/blob/main/Class3_Dyson_Diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Class 3 April 8 2021

# %% [markdown]
# Today's Agenda:
# *   [Class 1 & 2 Review](https://github.com/SciSharp/TensorFlow.NET/blob/master/docs/assets/syntax-comparision.png)
# *   [Business Case 1: Dyson](https://www.youtube.com/watch?v=fN7KJ46DHjU)
# *   [Sample Dataset 1: Diabetes](https://www.kaggle.com/uciml/pima-indians-diabetes-database/data)

# %% [markdown]
# ##Class 1 -> Variables, Lists, Functions, Conditionals

# %% [markdown]
# ###Programming Languages

# %% [markdown]
# *    Nearly all modern programming languages can do AI and use [machine learning libraries](https://www.tensorflow.org/api_docs)
#
# **REMEMBER:**
# We are NOT "really" learning Python here, but how to use someone else's LIBRARY!
#
#
#   *     C# [check this out](https://github.com/SciSharp/TensorFlow.NET/blob/master/docs/assets/syntax-comparision.png)
#   *     JavaScript
#   *     Java
#   *     Python
#   *     C++
#   *     Go

# %% [markdown]
# See Class 1 Notes for basics.
#
# *   variables (example usage: x=1)
# *   lists (example usage: [1,2,3])
# *   functions (example usage: def plus(a, b): return a + b)
# *   conditional (example usage: if this == that: print('equal') else: print('not equal'))

# %%
#variable
x=1 
print(x)

#list
y=[1, 2, 3]
print(y) 

#function
def plus(a, b): 
  return a + b 
print(plus(1,2))

#conditional
if x == x: 
  print('equal') 
else: 
  print('not equal')
# Out:
# 1
# [1, 2, 3]
# 3
# equal

# %% [markdown]
# ##Class 2 -> Pandas, DataFrame, Matplotlib, Plot

# %% [markdown]
# ###*Pandas Functions*

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/diabetes.csv',header=0)
#Convert to Pandas https://pypi.org/project/pandas/

# %%
data.describe() # Simple Column Statistics
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
data.columns # Print Column List
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
data.tail(2) # Print Last 2 Rows
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [2 rows x 9 columns]

# %%
data[data.columns[:4]].head(2) # Print First 5 Rows of First 4 Columns
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness
# 0            6      148             72             35
# 1            1       85             66             29

# %% [markdown]
# ###*Numpy*

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background') # Protip : Use Dark Backgrounds to HIGHLIGHT DIFFERENCES between data variables

# %%
import numpy as np # Generate Sample Data

data=np.random.normal(0,10,50)

# %%
data=pd.DataFrame(data) # Convert to Pandas
data.describe()
# Out:
#                0
# count  50.000000
# mean    1.652715
# std    10.096689
# min   -18.749943
# 25%    -3.921521
# 50%     0.613692
# 75%     7.045340
# max    30.290541

# %%
data_clean = data * 100 # Transformation Example
data_clean.describe()
# Out:
#                  0
# count    50.000000
# mean    165.271526
# std    1009.668874
# min   -1874.994294
# 25%    -392.152114
# 50%      61.369188
# 75%     704.533981
# max    3029.054085

# %%
data.plot.hist(bins=12,figsize=(20,10)) # Histogram Raw Data

# %%
data_clean.plot.hist(bins=12,figsize=(20,10)) # Histogram Transformed Data

# %% [markdown]
# ###*Matplotlib*

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(1,1,figsize=(20,10)) # Set Sizes
ax.set_xlabel('random data x')
ax.set_ylabel('random data y')
ax.plot(data[0], data_clean[0], '.') # Scatterplot Data

# %% [markdown]
# #[Business Case 1 : Dyson](https://www.youtube.com/watch?v=fN7KJ46DHjU)

# %% [markdown]
# #[>](https://www.kaggle.com/uciml/pima-indians-diabetes-database/data) Sample Dataset 1 : Diabetes

# %% [markdown]
# **Context**
# This dataset is originally from the National Institute of Diabetes and Digestive and Kidney Diseases. The objective of the dataset is to diagnostically predict whether or not a patient has diabetes, based on certain diagnostic measurements included in the dataset. Several constraints were placed on the selection of these instances from a larger database. In particular, all patients here are females at least 21 years old of Pima Indian heritage.
#
# **Content**
# The datasets consists of several medical predictor variables and one target variable, Outcome. Predictor variables includes the number of pregnancies the patient has had, their BMI, insulin level, age, and so on.

# %% [markdown]
# ###Import CSV Data

# %%
import pandas as pd # Import Pandas Module:

# %%
diabetes = pd.read_csv( # Load the diabetes dataset from CSV:
      'https://raw.githubusercontent.com/plotly/datasets/master/diabetes.csv',header=0)

# %%
diabetes # Show diabetes data:
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# ###Histograms

# %%
import matplotlib.pyplot as plt
#ax.title.set_fontsize(20)
plt.figure(figsize=(20,20))
plt.rcParams.update({'font.size': 22})

# %% [markdown]
# ####*One Variable*

# %%
Glucose = diabetes[['Glucose']]
Glucose.plot.hist(figsize=(20,10),bins=20,fontsize=20)

# %% [markdown]
# ####*One Variable (Colored By Another Variable)*

# %%
outcomes = diabetes.Outcome.unique()
plt.figure(figsize=(20,10))
plt.hist([diabetes.loc[diabetes.Outcome == x, 'Glucose'] for x in outcomes], label=outcomes,stacked=True, bins=20)
plt.legend(outcomes)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ####*Two Variables*

# %%
GlucoseAndBP = diabetes[['Glucose', 'BloodPressure']]
GlucoseAndBP.plot.hist(figsize=(20,10), bins=20, alpha=0.5)

# %% [markdown]
# ####*All Variables*

# %%
diabetes.hist(bins=30, figsize=(30, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f35afd4cad0>,
# ...
#       dtype=object)

# %% [markdown]
# ###Transform

# %%
diabetes['Insulin']= (diabetes['Insulin'] / 7) # Scale Columns By Linear Transformations to Improve Scatterplot:
diabetes['DiabetesPedigreeFunction']= (diabetes['DiabetesPedigreeFunction'] * 40)
diabetes['Pregnancies']= (diabetes['Pregnancies'] * 5)
diabetes['Glucose']= (diabetes['Glucose'] / 3)
diabetes['BMI']= (diabetes['BMI'] / 1)
diabetes['Outcome']= (diabetes['Outcome'] * 1)

# %% [markdown]
# ###Boxplot

# %%
diabetes.boxplot(figsize=(25,10),fontsize=20 # Create Dataset Boxplot
              ,grid=False,flierprops=dict(marker='o', markerfacecolor='g', markersize=8, linestyle='none', markeredgecolor='g'))

# %% [markdown]
# ###Scatterplot by Size

# %%
diabetes.plot.scatter(x='Glucose', # Create Scatterplot By Size
                      y='BloodPressure',
                      s='Insulin',
                      figsize=(25, 10))

# %% [markdown]
# ###Scatterplot by Color

# %%
fig, ax = plt.subplots() # WATCH OUT BUG! https://stackoverflow.com/questions/43121584/matplotlib-scatterplot-x-axis-labels
diabetes.plot.scatter(x='Insulin', # Create Scatterplot By Color
                      y='Glucose',
                      c='Outcome',
                      colormap='viridis',
                      figsize=(25, 10),ax=ax)

# %% [markdown]
# ###Correlations

# %%
correlations=diabetes.corr() # Generate Dataset Correlation Matrix

# %%
correlations # Show correlations
# Out:
#                           Pregnancies   Glucose  ...       Age   Outcome
# Pregnancies                  1.000000  0.129459  ...  0.544341  0.221898
# Glucose                      0.129459  1.000000  ...  0.263514  0.466581
# BloodPressure                0.141282  0.152590  ...  0.239528  0.065068
# SkinThickness               -0.081672  0.057328  ... -0.113970  0.074752
# Insulin                     -0.073535  0.331357  ... -0.042163  0.130548
# BMI                          0.017683  0.221071  ...  0.036242  0.292695
# DiabetesPedigreeFunction    -0.033523  0.137337  ...  0.033561  0.173844
# Age                          0.544341  0.263514  ...  1.000000  0.238356
# Outcome                      0.221898  0.466581  ...  0.238356  1.000000
#
# [9 rows x 9 columns]

# %%
import seaborn as sn # Import Module Seaborn:

# %%
plt.subplots(figsize=(25,10)) # Generate Dataset Correlations Heatmap:
sn.diverging_palette(250, 30, l=65, center="dark", as_cmap=True)
sn.heatmap(correlations, annot=False,vmin=-1, vmax=1,center=0)
plt.xticks(rotation=43)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5]),
#  <a list of 9 Text major ticklabel objects>)

# %% [markdown]
# ###**Homework: Did our linear transformations affect the correlations?**

# %% [markdown]
# **NO**
# Linear transformations have no effect on Pearson's correlation coefficient. But, they are tools to help us for interpretation and visualization!
#
# **EXAMPLE:** the correlation between height and weight is the same regardless of whether height is measured in inches, feet, centimeters or even miles.
